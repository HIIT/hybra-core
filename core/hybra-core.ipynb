# %% [markdown]
# ## testi

# %%
# %matplotlib notebook

import data_loader
import descriptives
import timeline
import network
import wordclouds

import mpld3
from matplotlib import pyplot as plt

data = data_loader.load_facebook()
data2 = data_loader.load_facebook( terms = ['nokkahuilu'])

# %%
descriptives.describe( data )
# Out:
# Post together 46509 posts
# First post 2006-07-27 09:00:00
# Last post 2016-11-13 19:31:53
# Number of authors 5727

# %%
timeline.create_timeline( data )
mpld3.enable_notebook()
# Out:
# <img src="data:image/png;base64,...">

# %%
network.create_network( data2 )
mpld3.enable_notebook()
# Out:
# <img src="data:image/png;base64,...">

# %%
wordclouds.create_wordcloud( data )
mpld3.enable_notebook()
# Out:
# Distinct words: 359614
#
# 10 most common words:
# 1. ei - 45957
# 2. että - 33051
# 3. se - 20901
# 4. kun - 17083
# 5. niin - 17002
# 6. ole - 16613
# 7. jos - 14488
# 8. mutta - 13864
# 9. that - 11731
# 10. nyt - 11437
# <img src="data:image/png;base64,...">
