# %% [markdown]
# ## Examples of using hybra-core

# %%
# %matplotlib notebook

import hybra
import mpld3

data = hybra.load_data()
data2 = hybra.load_data( data_folder = 'facebook' )
data3 = hybra.load_data( data_folder = 'media' )
data4 = hybra.load_data( ['nokkahuilu'], 'facebook' )
# Out:
# /Users/paakkoj6/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Data directory is not a git repo. Data might not be up-to-date!

# %%
hybra.describe( data )
# Out:
# load_facebook
# Post together 46509 posts
# First post 2006-07-27 09:00:00
# Last post 2016-11-13 19:31:53
# Number of authors 5727
#
#
# load_media
# Post together 9988 posts
# First post 2016-08-17 07:21:00
# Last post 2016-12-01 15:54:00
# Number of authors 533

# %%
hybra.create_timeline( data3 )
# Out:
# <img src="data:image/png;base64,...">

# %%
hybra.create_network( data4 )
# Out:
# <img src="data:image/png;base64,...">

# %%
hybra.create_wordcloud( data2 )
# Out:
# Distinct words: 359614
#
# 10 most common words:
# 1. ei - 45957
# 2. että - 33051
# 3. se - 20901
# 4. kun - 17083
# 5. niin - 17002
# 6. ole - 16613
# 7. jos - 14488
# 8. mutta - 13864
# 9. that - 11731
# 10. nyt - 11437
# <img src="data:image/png;base64,...">
