# %% [markdown]
# ## testi

# %%
import data_loader
import descriptives

data = data_loader.load_facebook()
descriptives.describe( data )
# Out:
# Post together 4354 posts
# First post 2006-07-27 09:00:00
# Last post 2016-11-13 13:14:53
# Number of authors 53
# Comments 1923

# %%
# %matplotlib notebook

import data_loader
import timeline
from matplotlib import pyplot as plt

data = data_loader.load_facebook()
timeline.create_timeline( data )
plt.show()
# Out:
# /Users/paakkoj6/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook

import data_loader
import network
from matplotlib import pyplot as plt

data = data_loader.load_facebook()
network.create_network( data )
plt.show()
# Out:
# /Users/paakkoj6/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook

import data_loader
import wordclouds
from matplotlib import pyplot as plt

data = data_loader.load_facebook()
wordclouds.create_wordcloud( data )
plt.show()
# Out:
# Distinct words: 27056
#
# 10 most common words:
# 1. it - 683
# 2. that - 623
# 3. sports - 618
# 4. liikkukaa - 611
# 5. all - 582
# 6. we - 576
# 7. with - 562
# 8. are - 554
# 9. c3 - 527
# 10. be - 526
# <img src="data:image/png;base64,...">
