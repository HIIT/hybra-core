# %% [markdown]
# ## testi

# %%
import data_loader
import descriptives

data = data_loader.load_facebook( terms = 'ei_vihapuheelle' )
descriptives.describe( data )
# Out:
# Post together 45959 posts
# First post 2006-07-27 09:00:00
# Last post 2016-11-13 19:31:53
# Number of authors 5699

# %%
# %matplotlib notebook

import data_loader
import timeline
from matplotlib import pyplot as plt

data = data_loader.load_facebook( terms = 'ei_vihapuheelle' )
timeline.create_timeline( data )
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook

import data_loader
import network
from matplotlib import pyplot as plt

data = data_loader.load_facebook( terms = ['ei_vihapuheelle'] )
network.create_network( data )
plt.show()
# Out:
# /Users/paakkoj6/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook

import data_loader
import wordclouds
from matplotlib import pyplot as plt

data = data_loader.load_facebook( )
wordclouds.create_wordcloud( data )
plt.show()
# Out:
# Distinct words: 358727
#
# 10 most common words:
# 1. ei - 45863
# 2. että - 32973
# 3. se - 20860
# 4. kun - 17058
# 5. niin - 16987
# 6. ole - 16579
# 7. jos - 14463
# 8. mutta - 13829
# 9. that - 11688
# 10. nyt - 11411
# <img src="data:image/png;base64,...">
